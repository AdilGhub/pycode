# %%
import seaborn as sns
import pandas as pd
df = sns.load_dataset("titanic")

# %%
df.to_csv("df.csv",index=False)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df["class"].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
df["embark_town"].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
df["alive"].value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
mask=((df["alive"]=="yes") & (df["who"]=="woman"))
df[mask].shape
# Out:
# (205, 15)

# %%
mask=((df["alive"]=="yes") & (df["who"]=="man"))
df[mask].shape
# Out:
# (88, 15)

# %%
df["alive"].value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.rename(columns={'first class':'customer_class'},inplace=True)

# %%
df["customer_class"].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df["customer_class"].nunique()
# Out:
# 3

# %%
sns.scatterplot(data=df,x="age",y="fare")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.lineplot(data=df,x="age",y="fare")
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.lineplot(data=df,x="pclass",y="fare")
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
sns.scatterplot(data=df,x="pclass",y="fare")
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import plotly.express as px
# %matplotlib inline

# %%
a=px.data.gapminder()
a
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
a["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
a["country"].nunique()
# Out:
# 142

# %%
mask=a["country"]=="India"
ind=a[mask]
ind
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
sns.lineplot(data=ind,x="year",y="lifeExp")
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.lineplot(data=ind,x="year",y="pop")
# Out:
# <Axes: xlabel='year', ylabel='pop'>

# %%
sns.lineplot(data=ind,x="year",y="gdpPercap")
# Out:
# <Axes: xlabel='year', ylabel='gdpPercap'>

# %%
mask=a["country"]=="Japan"
jpn=a[mask]
jpn
# Out:
#     country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 792   Japan      Asia  1952   63.030   86459025   3216.956347       JPN
# 793   Japan      Asia  1957   65.500   91563009   4317.694365       JPN
# 794   Japan      Asia  1962   68.730   95831757   6576.649461       JPN
# 795   Japan      Asia  1967   71.430  100825279   9847.788607       JPN
# 796   Japan      Asia  1972   73.420  107188273  14778.786360       JPN
# 797   Japan      Asia  1977   75.380  113872473  16610.377010       JPN
# 798   Japan      Asia  1982   77.110  118454974  19384.105710       JPN
# 799   Japan      Asia  1987   78.670  122091325  22375.941890       JPN
# 800   Japan      Asia  1992   79.360  124329269  26824.895110       JPN
# 801   Japan      Asia  1997   80.690  125956499  28816.584990       JPN
# 802   Japan      Asia  2002   82.000  127065841  28604.591900       JPN
# 803   Japan      Asia  2007   82.603  127467972  31656.068060       JPN
#
#      iso_num
# 792      392
# ...

# %%
sns.lineplot(data=jpn,x="year",y="lifeExp")
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.lineplot(data=jpn,x="year",y="pop")
# Out:
# <Axes: xlabel='year', ylabel='pop'>

# %%
sns.lineplot(data=jpn,x="year",y="gdpPercap")
# Out:
# <Axes: xlabel='year', ylabel='gdpPercap'>

# %%
mask=a["country"]=="Germany"
ger=a[mask]
ger
# Out:
#      country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 564  Germany    Europe  1952   67.500  69145952   7144.114393       DEU
# 565  Germany    Europe  1957   69.100  71019069  10187.826650       DEU
# 566  Germany    Europe  1962   70.300  73739117  12902.462910       DEU
# 567  Germany    Europe  1967   70.800  76368453  14745.625610       DEU
# 568  Germany    Europe  1972   71.000  78717088  18016.180270       DEU
# 569  Germany    Europe  1977   72.500  78160773  20512.921230       DEU
# 570  Germany    Europe  1982   73.800  78335266  22031.532740       DEU
# 571  Germany    Europe  1987   74.847  77718298  24639.185660       DEU
# 572  Germany    Europe  1992   76.070  80597764  26505.303170       DEU
# 573  Germany    Europe  1997   77.340  82011073  27788.884160       DEU
# 574  Germany    Europe  2002   78.670  82350671  30035.801980       DEU
# 575  Germany    Europe  2007   79.406  82400996  32170.374420       DEU
#
#      iso_num
# 564      276
# ...

# %%
sns.lineplot(data=ger,x="year",y="lifeExp")
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.lineplot(data=ger,x="year",y="pop")
# Out:
# <Axes: xlabel='year', ylabel='pop'>

# %%
sns.lineplot(data=ger,x="year",y="gdpPercap")
# Out:
# <Axes: xlabel='year', ylabel='gdpPercap'>

# %%
mask=a["country"]=="China"
ch=a[mask]
ch
# Out:
#     country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288   China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289   China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290   China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291   China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292   China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293   China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294   China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295   China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296   China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297   China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298   China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# 299   China      Asia  2007  72.96100  1318683096  4959.114854       CHN
#
#      iso_num
# ...

# %%
sns.lineplot(data=ger,x="year",y="lifeExp")
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.lineplot(data=ger,x="year",y="pop")
# Out:
# <Axes: xlabel='year', ylabel='pop'>

# %%
sns.lineplot(data=ger,x="year",y="gdpPercap")
# Out:
# <Axes: xlabel='year', ylabel='gdpPercap'>

# %%
mask=a["country"]=="Saudi Arabia"
sa=a[mask]
sa
# Out:
#            country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 1308  Saudi Arabia      Asia  1952   39.875   4005677   6459.554823       SAU
# 1309  Saudi Arabia      Asia  1957   42.868   4419650   8157.591248       SAU
# 1310  Saudi Arabia      Asia  1962   45.914   4943029  11626.419750       SAU
# 1311  Saudi Arabia      Asia  1967   49.901   5618198  16903.048860       SAU
# 1312  Saudi Arabia      Asia  1972   53.886   6472756  24837.428650       SAU
# 1313  Saudi Arabia      Asia  1977   58.690   8128505  34167.762600       SAU
# 1314  Saudi Arabia      Asia  1982   63.012  11254672  33693.175250       SAU
# 1315  Saudi Arabia      Asia  1987   66.295  14619745  21198.261360       SAU
# 1316  Saudi Arabia      Asia  1992   68.768  16945857  24841.617770       SAU
# 1317  Saudi Arabia      Asia  1997   70.533  21229759  20586.690190       SAU
# 1318  Saudi Arabia      Asia  2002   71.626  24501530  19014.541180       SAU
# ...

# %%
sns.lineplot(data=sa,x="year",y="lifeExp")
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.lineplot(data=sa,x="year",y="pop")
# Out:
# <Axes: xlabel='year', ylabel='pop'>
