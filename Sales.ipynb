# %%
import numpy as np
import pandas as pd
import seaborn as sns
ad=pd.read_csv("adver.csv")
ad
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
ad.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sns.scatterplot(data=ad,x="TV",y="Sales")
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(data=ad,x="Radio",y="Sales")
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(data=ad,x="Newspaper",y="Sales")
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
ad.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sns.barplot(data=ad,x="TV",y="Sales")
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %% [markdown]
# sns.lineplot(data=ad,x="TV",y="Sales")

# %%
sns.histplot(data=ad,x="TV",y="Sales")
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.stripplot(data=ad,x="TV",y="Sales")
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
ad.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
import matplotlib.pyplot as plt

# %%
sns.pairplot(ad,x_vars=["TV","Newspaper","Radio","Sales"])

# %%
#import statsmodels.api as sm
import sklearn

# %%
X=ad["TV"]
y=ad["Sales"]

# %%
from sklearn.linear_model import LinearRegression

# %%
TV=ad[["TV"]].values
Sales=ad[["Sales"]].values

model=LinearRegression()
model.fit(TV,Sales)
# Out:
# LinearRegression()

# %%
TV_new=[[230]]
predicted_sales=model.predict(TV_new)
print("predicted sales for TV value :",predicted_sales[0][0])
# Out:
# predicted sales for TV value : 19.73171869622843
