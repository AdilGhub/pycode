# %%
import seaborn as sns
import pandas as pd
import numpy as np
tips_data = sns.load_dataset("tips")

# %%
tips_data.to_csv("tips_data.csv",index=False)

# %%
import pandas as pd
d=pd.read_csv("tips_data.csv")
d
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# 1)The above data set is of resturant
# 2)the given data had 7 coloumn and 244 rows
# 3)The given data is in proper shape in data types
# 4)The coloumn which are specified about total_bill,tip,sex,smoker,day,time and size

# %%
d.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
d.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
d.size
# Out:
# 1708

# %%
d.shape
# Out:
# (244, 7)

# %%
d.ndim
# Out:
# 2

# %%
d.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
d.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
d[["tip","total_bill","sex"]]
# Out:
#       tip  total_bill     sex
# 0    1.01       16.99  Female
# 1    1.66       10.34    Male
# 2    3.50       21.01    Male
# 3    3.31       23.68    Male
# 4    3.61       24.59  Female
# ..    ...         ...     ...
# 239  5.92       29.03    Male
# 240  2.00       27.18  Female
# 241  2.00       22.67    Male
# 242  1.75       17.82    Male
# 243  3.00       18.78  Female
#
# [244 rows x 3 columns]

# %%
d
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
d.values
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object)

# %%
d.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 75        10.51  1.25    Male     No   Sat  Dinner     2
# 22        15.77  2.23  Female     No   Sat  Dinner     2
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2
# 78        22.76  3.00    Male     No  Thur   Lunch     2
# 86        13.03  2.00    Male     No  Thur   Lunch     2
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 17        16.29  3.71    Male     No   Sun  Dinner     3
# 90        28.97  3.00    Male    Yes   Fri  Dinner     2

# %%
d.isnull().sum()   #check the condition if satisfy add them
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
d.isnull()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
d.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
d["total_bill"].duplicated().sum()
# Out:
# 15

# %%
d.iloc[0:20]
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
d.iloc[0:5,0:3]
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
d.iloc[[4,66,28]]    #for specifying given the rows
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 66       16.45  2.47  Female     No  Sat  Dinner     2
# 28       21.70  4.30    Male     No  Sat  Dinner     2

# %%
d.iloc[1:4,3:6]
# Out:
#   smoker  day    time
# 1     No  Sun  Dinner
# 2     No  Sun  Dinner
# 3     No  Sun  Dinner

# %%
d.loc[8]
# Out:
# total_bill     15.04
# tip             1.96
# sex             Male
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 8, dtype: object

# %%
mask=d["time"]=="Dinner"
mask
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: time, Length: 244, dtype: bool

# %%
d[mask].shape
# Out:
# (176, 7)

# %%
mask=d["smoker"]=="No"

# %%
d[mask].shape
# Out:
# (151, 7)

# %%
mask=d["smoker"]=="Yes"

# %%
d[mask].shape
# Out:
# (93, 7)

# %%
mask=d["sex"]=="Male"
d[mask].shape
# Out:
# (157, 7)

# %%
mask=d["sex"]=="Female"
d[mask].shape
# Out:
# (87, 7)

# %%
mask=(d["total_bill"]>=30.00)
d[mask].shape
# Out:
# (32, 7)

# %%
mask=d["tip"]>=3.0
d[mask].shape
# Out:
# (121, 7)

# %%
mask=(d["total_bill"]>=30.00)
mask.sum()
# Out:
# 32

# %%
d
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
mask=((d["sex"]=="Male") & (d["smoker"]=="Yes"))
d[mask].shape
# Out:
# (60, 7)

# %%
mask=((d["sex"]=="Female") & (d["smoker"]=="Yes"))
d[mask].shape
# Out:
# (33, 7)

# %%
mask=((d["sex"]=="Male") & (d["total_bill"]>=15.0))
d[mask].shape
# Out:
# (113, 7)

# %%
mask=((d["sex"]=="Female") & (d["total_bill"]>=15.0))
d[mask].shape
# Out:
# (51, 7)

# %%
mask=((d["sex"]=="Male") & (d["total_bill"]>=20.0) & (d["smoker"]=="Yes"))
d[mask].shape
# Out:
# (31, 7)

# %% [markdown]
# How many men are coming at weekend night in the resturant

# %%
mask=((d["sex"]=="Male") & ((d["day"]=="Sun") | (d["day"]=="Sat")) & (d["time"]=="Dinner"))
d[mask].shape
# Out:
# (117, 7)

# %%
# How many women are smoking and paying good bills or tips
mask=((d["sex"]=="Female") & (d["smoker"]=="Yes") & ((d["total_bill"]>=15.0) | (d["tip"]>=3.0)))
d[mask].shape
# Out:
# (21, 7)

# %%
d["state"]="Telangana"

# %%
d["contry"]="India"

# %%
d
# Out:
#      total_bill   tip     sex smoker   day    time  size      state contry
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Telangana  India
# 1         10.34  1.66    Male     No   Sun  Dinner     3  Telangana  India
# 2         21.01  3.50    Male     No   Sun  Dinner     3  Telangana  India
# 3         23.68  3.31    Male     No   Sun  Dinner     2  Telangana  India
# 4         24.59  3.61  Female     No   Sun  Dinner     4  Telangana  India
# ..          ...   ...     ...    ...   ...     ...   ...        ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  Telangana  India
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  Telangana  India
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  Telangana  India
# 242       17.82  1.75    Male     No   Sat  Dinner     2  Telangana  India
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Telangana  India
#
# [244 rows x 9 columns]

# %%
d["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
d["size"].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
d["day"].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
d["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
d["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
d["total_bill"].value_counts()
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
#         ..
# 24.71    1
# 21.16    1
# 28.97    1
# 22.49    1
# 18.78    1
# Name: total_bill, Length: 229, dtype: int64

# %%
d.sort_values("tip",ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size      state contry
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  Telangana  India
# 212       48.33   9.00    Male     No   Sat  Dinner     4  Telangana  India
# 23        39.42   7.58    Male     No   Sat  Dinner     4  Telangana  India
# 59        48.27   6.73    Male     No   Sat  Dinner     4  Telangana  India
# 141       34.30   6.70    Male     No  Thur   Lunch     6  Telangana  India
# ..          ...    ...     ...    ...   ...     ...   ...        ...    ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2  Telangana  India
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2  Telangana  India
# 111        7.25   1.00  Female     No   Sat  Dinner     1  Telangana  India
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1  Telangana  India
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2  Telangana  India
#
# [244 rows x 9 columns]

# %%
d.sort_values("tip",ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size      state contry
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  Telangana  India
# 212       48.33   9.00    Male     No   Sat  Dinner     4  Telangana  India
# 23        39.42   7.58    Male     No   Sat  Dinner     4  Telangana  India
# 59        48.27   6.73    Male     No   Sat  Dinner     4  Telangana  India
# 141       34.30   6.70    Male     No  Thur   Lunch     6  Telangana  India
# ..          ...    ...     ...    ...   ...     ...   ...        ...    ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2  Telangana  India
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2  Telangana  India
# 111        7.25   1.00  Female     No   Sat  Dinner     1  Telangana  India
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1  Telangana  India
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2  Telangana  India
#
# [244 rows x 9 columns]

# %%
d.sort_values("sex")
# Out:
#      total_bill   tip     sex smoker   day    time  size      state contry
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Telangana  India
# 139       13.16  2.75  Female     No  Thur   Lunch     2  Telangana  India
# 137       14.15  2.00  Female     No  Thur   Lunch     2  Telangana  India
# 136       10.33  2.00  Female     No  Thur   Lunch     2  Telangana  India
# 135        8.51  1.25  Female     No  Thur   Lunch     2  Telangana  India
# ..          ...   ...     ...    ...   ...     ...   ...        ...    ...
# 43         9.68  1.32    Male     No   Sun  Dinner     2  Telangana  India
# 42        13.94  3.06    Male     No   Sun  Dinner     2  Telangana  India
# 41        17.46  2.54    Male     No   Sun  Dinner     2  Telangana  India
# 39        31.27  5.00    Male     No   Sat  Dinner     3  Telangana  India
# 156       48.17  5.00    Male     No   Sun  Dinner     6  Telangana  India
#
# [244 rows x 9 columns]

# %%
d.sort_values("total_bill",inplace=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size      state contry
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1  Telangana  India
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2  Telangana  India
# 111        7.25   1.00  Female     No   Sat  Dinner     1  Telangana  India
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2  Telangana  India
# 149        7.51   2.00    Male     No  Thur   Lunch     2  Telangana  India
# ..          ...    ...     ...    ...   ...     ...   ...        ...    ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3  Telangana  India
# 156       48.17   5.00    Male     No   Sun  Dinner     6  Telangana  India
# 59        48.27   6.73    Male     No   Sat  Dinner     4  Telangana  India
# 212       48.33   9.00    Male     No   Sat  Dinner     4  Telangana  India
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  Telangana  India
#
# [244 rows x 9 columns]

# %%
d
# Out:
#      total_bill   tip     sex smoker   day    time  size      state contry
# 0         16.99  1.01  Female     No   Sun  Dinner     2  Telangana  India
# 1         10.34  1.66    Male     No   Sun  Dinner     3  Telangana  India
# 2         21.01  3.50    Male     No   Sun  Dinner     3  Telangana  India
# 3         23.68  3.31    Male     No   Sun  Dinner     2  Telangana  India
# 4         24.59  3.61  Female     No   Sun  Dinner     4  Telangana  India
# ..          ...   ...     ...    ...   ...     ...   ...        ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  Telangana  India
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  Telangana  India
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  Telangana  India
# 242       17.82  1.75    Male     No   Sat  Dinner     2  Telangana  India
# 243       18.78  3.00  Female     No  Thur  Dinner     2  Telangana  India
#
# [244 rows x 9 columns]

# %%
d.sort_values("tip",axis=0)
# Out:
#      total_bill    tip     sex smoker   day    time  size      state contry
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1  Telangana  India
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2  Telangana  India
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2  Telangana  India
# 111        7.25   1.00  Female     No   Sat  Dinner     1  Telangana  India
# 0         16.99   1.01  Female     No   Sun  Dinner     2  Telangana  India
# ..          ...    ...     ...    ...   ...     ...   ...        ...    ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6  Telangana  India
# 59        48.27   6.73    Male     No   Sat  Dinner     4  Telangana  India
# 23        39.42   7.58    Male     No   Sat  Dinner     4  Telangana  India
# 212       48.33   9.00    Male     No   Sat  Dinner     4  Telangana  India
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  Telangana  India
#
# [244 rows x 9 columns]

# %%
df = sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
d.set_index("day",inplace=True)

# %%
d
# Out:
#       total_bill   tip     sex smoker    time  size      state contry
# day
# Sun        16.99  1.01  Female     No  Dinner     2  Telangana  India
# Sun        10.34  1.66    Male     No  Dinner     3  Telangana  India
# Sun        21.01  3.50    Male     No  Dinner     3  Telangana  India
# Sun        23.68  3.31    Male     No  Dinner     2  Telangana  India
# Sun        24.59  3.61  Female     No  Dinner     4  Telangana  India
# ...          ...   ...     ...    ...     ...   ...        ...    ...
# Sat        29.03  5.92    Male     No  Dinner     3  Telangana  India
# Sat        27.18  2.00  Female    Yes  Dinner     2  Telangana  India
# Sat        22.67  2.00    Male    Yes  Dinner     2  Telangana  India
# Sat        17.82  1.75    Male     No  Dinner     2  Telangana  India
# Thur       18.78  3.00  Female     No  Dinner     2  Telangana  India
#
# [244 rows x 8 columns]

# %%
d.reset_index(inplace=True)

# %%
d
# Out:
#       day  total_bill   tip     sex smoker    time  size      state contry
# 0     Sun       16.99  1.01  Female     No  Dinner     2  Telangana  India
# 1     Sun       10.34  1.66    Male     No  Dinner     3  Telangana  India
# 2     Sun       21.01  3.50    Male     No  Dinner     3  Telangana  India
# 3     Sun       23.68  3.31    Male     No  Dinner     2  Telangana  India
# 4     Sun       24.59  3.61  Female     No  Dinner     4  Telangana  India
# ..    ...         ...   ...     ...    ...     ...   ...        ...    ...
# 239   Sat       29.03  5.92    Male     No  Dinner     3  Telangana  India
# 240   Sat       27.18  2.00  Female    Yes  Dinner     2  Telangana  India
# 241   Sat       22.67  2.00    Male    Yes  Dinner     2  Telangana  India
# 242   Sat       17.82  1.75    Male     No  Dinner     2  Telangana  India
# 243  Thur       18.78  3.00  Female     No  Dinner     2  Telangana  India
#
# [244 rows x 9 columns]

# %%
sns.lineplot(data=d,x="total_bill",y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=d, x="total_bill" ,y="tip",hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=d,x="total_bill" ,y="tip",hue="sex" )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data=d, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=d, x="total_bill", hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.stripplot(data=d, x="day", y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(data=d, x="smoker", y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.stripplot(data=d, x="time", y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.stripplot(data=d, x="day", y="tip",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(data=d, x="time", y="tip",hue="sex")
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %%
sns.stripplot(data=d, x="smoker", y="tip",hue="sex")
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
d.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.barplot(data=d, x="day", y="total_bill", estimator=np.mean)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=d, x="time", y="total_bill", estimator=np.mean)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.barplot(data=d, x="smoker", y="total_bill", estimator=np.mean)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.barplot(data=d, x="sex", y="total_bill", estimator=np.mean)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(data=d, x="smoker", y="total_bill",hue="day", estimator=np.mean)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>
